# %% [markdown]
# <a href="https://colab.research.google.com/github/Rouba-Os/AI-Course/blob/main/Assignment13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install -y git
# !git config --global user.email "rouba.osko@students.williscollege.com"
# !git config --global user.name "Rouba-Os"

print("Git configured successfully")

# %%
# !git clone https://github.com/Rouba-Os/AI-Course.git
# %cd AI-Course
# !ls

# %%
# !git status

# %% [markdown]
# # Introduction to Generative AI and its significance
#
# Generative AI is a type of AI that creates new content like text, images, or code by learning patterns from data, for example ChatGPT.
#
# Significance:
# It is important because it saves time, boosts creativity, and helps in many areas like education, business, and healthcare.

# %% [markdown]
# # Dataset Preparation
# Used a public dataset from Project Gutenberg (Alice in Wonderland) to demonstrate text-based AI generation.

# %%
text_data = """
Alice was beginning to get very tired of sitting by her sister on the bank,
and of having nothing to do: once or twice she had peeped into the book her sister was reading,
but it had no pictures or conversations in it
"""

print(text_data[:300])

# %% [markdown]
# # GPTs architecture and functionality
#
# Architecture:
# It breaks text into small pieces called tokens
# Converts them into numbers (embeddings)
# Uses transformer layers with attention to understand context
# Predicts the next word using an output layer
#
# Functionality:
# It is trained on large amounts of text (pre-training)
# Then it generates text by predicting one word at a time based on what came before

# %%
# Install the necessary libraries and import the required modules
# !pip install transformers torch

import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# Load the pre-trained model and tokenizer
model_name = "gpt2"
model = GPT2LMHeadModel.from_pretrained(model_name)
tokenizer = GPT2Tokenizer.from_pretrained(model_name)

# %%
# Define function for text generation
def generate_text(prompt, max_length=120, temperature=1.0, top_k=40, top_p=0.9):

    input_ids = tokenizer.encode(prompt, return_tensors="pt")

    output = model.generate(
        input_ids,
        max_length=max_length,
        temperature=temperature,
        top_k=top_k,
        top_p=top_p,
        do_sample=True
    )

    return tokenizer.decode(output[0], skip_special_tokens=True)

# %%
# Experiment with different prompts and parameters
## Basic Generation
prompt = "Summer time is"
print("Basic text generation")
print(generate_text(prompt))

# %%
## Controlling output length
prompt = "Artificial intelligence will change"
print("Controlling output length")
print(generate_text(prompt, max_length=60))
print(generate_text(prompt, max_length=140))

# %%
## Temperature Effect
prompt = "business intelligence in healthcare sector will improve"

print("Low temperature:")
print(generate_text(prompt, temperature=0.3))

print("\nHigh temperature:")
print(generate_text(prompt, temperature=1.4))

# %%
## Using top_k and top_p
prompt = "Future jobs will require skills in"

print("Using top_k and top_p")
print("Default settings:")
print(generate_text(prompt))
print("\ntop_k and top_p:")
print(generate_text(prompt, top_k=20, top_p=0.7))

# %%
## Prompt engineering
print("Prompt engineering")
base_prompt = "Write a short story about"
topics = ["a self-driving car making decisions", "how automation is changing the workplace", "a robot working in a restaurant"]

for topic in topics:
    full_prompt = f"{base_prompt} {topic}"
    print(f"Topic: {topic}")
    print(generate_text(full_prompt, max_length=140))
    print("\n" + "-"*30 + "\n")

# %%
# Application example
def article_generator(topic):
    return generate_text(f"Write a short article about {topic}:", max_length=180)

print("Application example")
print(article_generator("AI in finance"))

# %% [markdown]
# # Ethical Considerations
# Generative AI has several ethical concerns:
# - Bias in generated outputs
# - Fake or misleading information
# - Copyright issues
# - Privacy risks
# - High energy consumption
#
# Solutions include:
# - Using diverse datasets
# - Human review
# - Fairness evaluation
# - Responsible AI guidelines

# %% [markdown]
# # Conclusion
# This assignment shows how GPT-2 can generate human-like text using prompt engineering and parameter tuning.
#
# I explored:
# - GPT architecture
# - Dataset usage
# - Text generation
# - Temperature and sampling control
# - Real-world applications
#
# Generative AI is powerful but must be used responsibly.

# %%
# !git add Assignment13.ipynb

# %%
! git commit -m "Add Assignment 13 "

# %%
print("1. In Google Colab, go to the 'Edit' menu at the top of the page.")
print("2. Select 'Clear all outputs'.")
print("3. Save your notebook (File -> Save a copy in GitHub or File -> Save) and then try committing and pushing to GitHub again.")
print("\nThis process removes any potentially problematic metadata from cell outputs, which often resolves GitHub rendering issues.")
